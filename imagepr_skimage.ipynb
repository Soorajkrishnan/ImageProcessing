# %% [markdown]
# <a href="https://colab.research.google.com/github/Soorajkrishnan/ImageProcessing/blob/master/imagepr_skimage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Processing

# %% [markdown]
# ##Using SKimage

# %%
from skimage import data,io,filters #importing libraries from skimage
import matplotlib.pyplot as plt #ploting library
import numpy as np #mathematical libraries
from google.colab import drive #library for linking drive

# %%
drive.mount('/content/drive')#linking google drive data to colab

# %%
A=io.imread("/content/drive/My Drive/Workshop/cat.jpg")

# %%
io.imshow(A)#showing image using skimage

# %%
A.shape #for showing the dimentions (height,width,channel(rgb))
# Out:
# (342, 250, 3)

# %%
sobel_filtering=filters.sobel(A[:,:,0])#red channel
#sobel_filtering1=filters.sobel(A[:,:,1])#blue channel
#sobel_filtering2=filters.sobel(A[:,:,2])#green channnel
#sobl=sobel_filtering+sobel_filtering1+sobel_filtering2 #rgb channel
io.imshow(sobel_filtering)
#io.imsave('cat_sobel.jpg',sobl)

# %%
R=plt.imshow(A[:,:,0],cmap='Reds')
plt.show(R)

# %%
G=plt.imshow(A[:,:,1],cmap='Greens')
plt.show(G)

# %%
plt.show(B)

# %%
B=plt.imshow(A[:,:,2],cmap='Blues')
